# %% [markdown]
# **Singly Linked List**

# %%
class tasknode:
    def __init__(self, data):
        self.data = data
        self.next = None

class tasklist:
    def __init__(self):
        self.head = None

    def add_task(self, task):
        new_task = tasknode(task)
        if not self.head:
            self.head = new_task
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_task

    def show_tasks(self):
        if not self.head:
            print("\nTidak ada mata kuliah hari ini!")
            return

        print("\nJadwal mata kuliah hari Jumat:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.data}")
            current = current.next
            count += 1

task_list = tasklist()

num_tasks = int(input("Masukkan jumlah mata kuliah: "))

for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan mata kuliah ke-{i}: ")
    task_list.add_task(task_name)

task_list.show_tasks()
# Out:
# Masukkan jumlah mata kuliah: 2
# Masukkan mata kuliah ke-1: agama
# Masukkan mata kuliah ke-2: bahasa
#
# Jadwal mata kuliah hari Jumat:
# 1. agama
# 2. bahasa

# %% [markdown]
# **Doubly Linked List**

# %%
class pagenode:
    def __init__(self, folder):
        self.folder = folder
        self.next = None
        self.prev = None

class browserhistory:
    def __init__(self):
        self.current = None

    def visit_page(self,folder):
        new_page = pagenode(folder)
        if not self.current:
            self.current = new_page
        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page

    def show_history(self):
        if not self.current:
            print("\nTidak ada folder yang dikunjungi!")
            return

        print("\nRiwayat Navigasi Folder :")
        temp = self.current
        while temp.prev:
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.folder}")
            temp = temp.next
            count += 1

    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke folder sebelumnya: {self.current.folder}")
        else:
            print("\nTidak bisa kembali, ini adalah halaman pertama File Explorer.")
class pagenode:
    def __init__(self, folder):
        self.folder = folder
        self.next = None
        self.prev = None

class browserhistory:
    def __init__(self):
        self.current = None

    def visit_page(self,folder):
        new_page = pagenode(folder)
        if not self.current:
            self.current = new_page
        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page

    def show_history(self):
        if not self.current:
            print("\nTidak ada folder yang dikunjungi!")
            return

        print("\nRiwayat Navigasi Folder:")
        temp = self.current
        while temp.prev:
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.folder}")
            temp = temp.next
            count += 1

    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"\n Anda kembali ke folder sebelumnya: {self.current.folder}")
        else:
            print("\nTidak bisa kembali, ini adalah halaman pertama File Explorer.")

    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"\n Anda maju ke {self.current.folder}")
        else:
            print("\n Tidak bisa maju, ini adalah folder terakhir.")

history = browserhistory()

num_pages = int(input("\nMasukkan jumlah folder yang dikunjungi:"))

for i in range(1, num_pages + 1):
    url = input(f"Masukkan folder ke-{i}:")
    history.visit_page(url)

history.show_history()

while True:
    command = input("\n Tekan 'b' untuk kembali, tekan 'f' untuk maju, atau tekan 'x' untuk keluar: ")
    if command == 'b':
        history.go_back()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\n Keluar dari folder.")
        break
    else:
        print("\n Perintah tidak valid. Silakan coba lagi.")
# Out:
# Masukkan jumlah folder yang dikunjungi:2
# Masukkan folder ke-1:hoho
# Masukkan folder ke-2:hihi
#
# Riwayat Navigasi Folder:
# 1. hoho
# 2. hihi
#
#  Tekan 'b' untuk kembali, tekan 'f' untuk maju, atau tekan 'x' untuk keluar: f
#
#  Tidak bisa maju, ini adalah folder terakhir.
#
#  Tekan 'b' untuk kembali, tekan 'f' untuk maju, atau tekan 'x' untuk keluar: x
#
#  Keluar dari folder.

# %% [markdown]
# **Circular Linked List**

# %%
class songnode:
    def __init__(self, title):
        self.title = title
        self.next = None

class playlist:
    def __init__(self):
        self.current = None

    def add_song(self, title):
        new_song = songnode(title)
        if not self.current:
            self.current = new_song
            self.current.next = self.current

        else:
            temp = self.current
            while temp.next != self.current:
                temp = temp.next
            temp.next = new_song
            new_song.next = self.current

    def show_playlist(self):
        if not self.current:
            print("\nPlaylist kosong!")
            return

        print("\nPlaylist:")
        temp = self.current
        count = 1
        while True:
            print(f"{count}. {temp.title}")
            temp = temp.next
            count += 1
            if temp == self.current:
                break

    def next_song(self):
        if self.current:
            self.current = self.current.next
            print(f"\n Memutar lagu: {self.current.title}")

playlist = playlist()

num_songs = int(input("\nMasukkan jumlah lagu yang ingin diputar: "))

for i in range(1, num_songs + 1):
    song_title = input(f"Masukkan judul lagu ke-{i}: ")
    playlist.add_song(song_title)

playlist.show_playlist()

while True:
    command = input("\n Tekan 'n' untuk memutar lagu berikutnya, atau tekan 'x' untuk keluar: ")
    if command == 'n':
        playlist.next_song()
    elif command == 'x':
        print("\n Keluar dari playlist.")
        break
    else:
        print("\n Perintah tidak dikenal")
# Out:
# Masukkan jumlah lagu yang ingin diputar: 2
# Masukkan judul lagu ke-1: w
# Masukkan judul lagu ke-2: we
#
# Playlist:
# 1. w
# 2. we
#
#  Tekan 'n' untuk memutar lagu berikutnya, atau tekan 'x' untuk keluar: n
#
#  Memutar lagu: we
#
#  Tekan 'n' untuk memutar lagu berikutnya, atau tekan 'x' untuk keluar: x
#
#  Keluar dari playlist.

# %% [markdown]
# **Operasi Dasar pada Linked List**

# %%
# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data  # Menyimpan nilai node
        self.next = None  # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None  # Awalnya, daftar kosong

    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, data, position):
        if position < 0:
            print(" Posisi tidak valid")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp:
                print("Posisi melebihi panjang daftar!")
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    # Menghapus elemen di awal
    def delete_at_beginning(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus.")
            return
        self.head = self.head.next

    # Menghapus elemen di akhir
    def delete_at_end(self):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus.")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
           temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position):
        if not self.head:
            print("Daftar kosong, tidak ada yang bisa dihapus.")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp.next or not temp.next:
                print("⚠️Posisi tidak ditemukan!")
                return
            temp = temp.next
        temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key):
        temp = self.head
        while temp:
            if temp.data == key:
                return
            temp = temp.next
        print(f"Elemen {key} tidak ditemukan dalam daftar.")

    # Membalik (reverse) Linked List
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Linked List
    def display(self):
        if not self.head:
            print("Daftar kosong!")
            return
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")

# ====== Program Utama (Main) ====== #

# Membuat objek Linked List

ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("\nMasukkan jumlah awal elemen dalam daftar:"))
for i in range(num_elements):
    data = int(input(f"Masukkan data ke-{i+1}: "))

    ll.add_at_end(data)

# Menu Operasi Linked List
while True:
    print("\nPilih Operasi:")
    print("1. Tambah elemen di Awal")
    print("2. Tambah elemen di Akhir")
    print("3. Tambah elemen di Posisi Tertentu")
    print("4. Hapus elemen di Awal")
    print("5. Hapus elemen di Akhir")
    print("6. Hapus elemen di Posisi Tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan :"))

    if choice == 1:
      data = int(input("Masukkan data yang ingin ditambahkan di awal: "))

      ll.add_at_beginning(data)
    elif choice == 2:
      data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))

      ll.add_at_end(data)
    elif choice == 3:
      position = int(input("Masukkan posisi untuk menambahkan data: "))
      data = int(input("Masukkan data yang ingin ditambahkan: "))

      ll.add_at_position(position, data)
    elif choice == 4:

      ll.delete_at_beginning()
    elif choice == 5:

      ll.delete_at_end()
    elif choice == 6:
      position = int(input("Masukkan posisi elemen yang ingin dihapus: "))

      ll.delete_at_position(position)
    elif choice == 7:
      key = int(input("Masukkan elemen yang ingin dicari: "))

      ll.search(key)
    elif choice == 8:

      ll.reverse()
      print(" Daftar berhasil dibalik!")
    elif choice == 9:

      ll.display()
    elif choice == 0:
      print("\n Keluar dari program.")
      break
    else:
      print("\n Pilihan tidak valid, silakan coba lagi.")
# Out:
# Masukkan jumlah awal elemen dalam daftar:1
# Masukkan data ke-1: 4
#
# Pilih Operasi:
# 1. Tambah elemen di Awal
# 2. Tambah elemen di Akhir
# 3. Tambah elemen di Posisi Tertentu
# 4. Hapus elemen di Awal
# 5. Hapus elemen di Akhir
# 6. Hapus elemen di Posisi Tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan :9
# 4 -> None
#
# Pilih Operasi:
# 1. Tambah elemen di Awal
# 2. Tambah elemen di Akhir
# 3. Tambah elemen di Posisi Tertentu
# 4. Hapus elemen di Awal
# 5. Hapus elemen di Akhir
# 6. Hapus elemen di Posisi Tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan :0
#
#  Keluar dari program.

# %% [markdown]
# **Tugas**

# %%
class Node:
    def __init__(self, name):
        self.name = name
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def append(self, name):
        new_node = Node(name)
        if not self.head:
            self.head = new_node
            self.head.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    def print_schedule(self, days):
        if not self.head:
            print("No security personnel available.")
            return

        temp = self.head
        print("\n⭐ Jadwal Piket Satpam Selama 2 Minggu: \n")
        for day in range(1, days + 1):
            print(f"Hari {day}: {temp.name}")
            temp = temp.next

# Input nama satpam
cll = CircularLinkedList()
names = []
for i in range(4):
    name = input(f"Masukkan nama satpam ke-{i+1}: ")
    names.append(name)
    cll.append(name)

# Cetak jadwal piket selama 14 hari
cll.print_schedule(14)
# Out:
# Masukkan nama satpam ke-1: Akhnaz Malik F
# Masukkan nama satpam ke-2: Muafifi Daffa F
# Masukkan nama satpam ke-3: Jabbar Hakim
# Masukkan nama satpam ke-4: Roby Ade P
#
# ⭐ Jadwal Piket Satpam Selama 2 Minggu:
#
# Hari 1: Akhnaz Malik F
# Hari 2: Muafifi Daffa F
# Hari 3: Jabbar Hakim
# Hari 4: Roby Ade P
# Hari 5: Akhnaz Malik F
# Hari 6: Muafifi Daffa F
# Hari 7: Jabbar Hakim
# Hari 8: Roby Ade P
# Hari 9: Akhnaz Malik F
# Hari 10: Muafifi Daffa F
# Hari 11: Jabbar Hakim
# Hari 12: Roby Ade P
# Hari 13: Akhnaz Malik F
# Hari 14: Muafifi Daffa F
